# %%
import pandas as pd 
ch = pd.read_excel(r'E:\COURSE - NAVTCC\List for students course vise.xlsx')
ch.head()
# Out:
#        Unnamed: 0 Artificial Intelligence (Robotics) - Merit List  \
# 0  Candidate Code                                            Name
# 1     CND-0020014                      Sheikh Muhammad Tabish Ali
# 2    CND-00289826                              Adnan Ali Khan Zai
# 3    CND-00216519                                   Urooj Qureshi
# 4     CND-0054628                                      Abdul bari
#
#            Unnamed: 2     Unnamed: 3   Unnamed: 4  \
# 0         Father Name           CNIC     Cell No.
# 1    Sheikh Aslam Ali  4240192255431  03350247249
# 2  Nasir Ali Khan Zai  4130425836361  03033366843
# 3       Pervez Akhter  4210135488756  03062412589
# 4             Shahzad  4240180663525  03342978992
#
#                                           Unnamed: 5
# 0                                     Postal Address
# 1  House # 67, Sector 16-A, Street # 03, Sir Syed...
# 2  Flat No. 304 Shamim Residency FB Area Block-9 ...
# ...

# %%
import pandas as pd 
ch = pd.read_excel(r'E:\COURSE - NAVTCC\List for students course vise.xlsx')
ch
# Out:
#         Unnamed: 0 Artificial Intelligence (Robotics) - Merit List  \
# 0   Candidate Code                                            Name
# 1      CND-0020014                      Sheikh Muhammad Tabish Ali
# 2     CND-00289826                              Adnan Ali Khan Zai
# 3     CND-00216519                                   Urooj Qureshi
# 4      CND-0054628                                      Abdul bari
# 5       CND-007700                                    Muhammad Ali
# 6      CND-0061423                                     Zaryab Raza
# 7     CND-00109133                             Faheem Abdul Raheem
# 8     CND-00277299                                Muhammed Mubeen
# 9      CND-0079382                              Junaid Ahmed Dahri
# 10     CND-0080171                         Muhammad Wajahat Ghauri
# 11     CND-0084996                            Muhammad Ammar Umer
# 12     CND-0099285                                Muhammad Liaquat
# ...

# %% [markdown]
# ### Creating a DataFrame within Jupyter Notebook

# %%
# importing the pandas library
import pandas as pd
 
 
# creating a dataframe object
student_register = pd.DataFrame()
 
# assigning values to the
# rows and columns of the
# dataframe
student_register['Name'] = ['Tabish',
                            'Zohaib',
                            'Mubeen',
                            'Shahmeer']
 
student_register['Age'] = [20, 19, 20, 14]
student_register['Student'] = [False, True,
                               True, False]
 
student_register
# Out:
#        Name  Age  Student
# 0    Tabish   20    False
# 1    Zohaib   19     True
# 2    Mubeen   20     True
# 3  Shahmeer   14    False

# %% [markdown]
# ### .describe() function

# %%
print(student_register.describe())
#print(student_register.info())
# Out:
#              Age
# count   4.000000
# mean   18.250000
# std     2.872281
# min    14.000000
# 25%    17.750000
# 50%    19.500000
# 75%    20.000000
# max    20.000000

# %% [markdown]
# ### .Shape attribute

# %%
print(student_register.shape)
# Out:
# (4, 3)

# %% [markdown]
# ### generating random  numbers and adding columns to the DataFrame

# %%
import pandas as pd
import numpy as np
ch = pd.DataFrame(np.random.randn(1000,5), columns = ['A', 'B', 'C', 'D', 'E']) 
ch
# Out:
#             A         B         C         D         E
# 0   -0.878265  1.508518 -0.126662 -1.773587 -0.600134
# 1    1.150984  0.285602 -1.538053 -0.663453 -0.093947
# 2    0.713647  0.608683  0.573210 -0.739533  0.946692
# 3   -0.162779 -0.985418  0.743566  0.274567  0.926970
# 4    1.620908  1.181394 -0.413749  1.013178  0.887584
# ..        ...       ...       ...       ...       ...
# 995  0.080869  0.175772 -0.971403  0.564332 -0.819754
# 996 -0.811313  1.305702  0.018993  1.107850  0.859641
# 997 -1.906549 -0.101503 -0.415561 -0.183364 -0.319265
# 998 -1.255169  0.339824 -0.038950  0.325627  3.382810
# 999 -0.744344  0.287677 -0.035041 -0.171262  0.505507
#
# [1000 rows x 5 columns]

# %%
import pandas as pd 
ch = pd.read_excel(r'E:\AI - SAYLANI COURSE - DATASETS\2.Merit List - Artificial Intelligence (Robotics).xlsx')
ch
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %% [markdown]
# ### calling a particular column

# %%
ch['Name']
# Out:
# 0     Sheikh Muhammad Tabish Ali
# 1             Adnan Ali Khan Zai
# 2                     Abdul bari
# 3                         M. Ali
# 4            Faheem Abdul Raheem
# 5                     M. Mubeen
# 6             Junaid Ahmed Dahri
# 7              M. Wajahat Ghauri
# 8                 M. Ammar Umer
# 9                   Norbin Rohan
# 10      Syeda Dania Batool Abidi
# 11             Faiza Zehra Agha
# 12              Najeeb ur Rehman
# 13                       Shahzad
# 14                    Zohaib ali
# 15            M. Shahmeer Shaikh
# 16            Syeda Hareem Nehal
# 17              Syed Faizan Ali
# 18               M. Farhan Fasih
# 19                    Rida Ameer
# 20              M. Annas Chowhan
# 21                     M. Younus
# 22           Fahad Hassan Ghouri
# 23             M. shahzaib uddin
# 24         Naveed ullah Mangnejo
# 25             Hamza Laeeq Ahmed
# 26               Alishba Rasheed
# 27                    Abdul Hadi
# ...

# %%
ch['Candidate Code']
# Out:
# 0      CND-0020014
# 1     CND-00289826
# 2      CND-0054628
# 3       CND-007700
# 4     CND-00109133
# 5     CND-00277299
# 6      CND-0079382
# 7      CND-0080171
# 8      CND-0084996
# 9     CND-00132394
# 10     CND-0029076
# 11     CND-0079781
# 12     CND-0020583
# 13     CND-0065053
# 14    CND-00171325
# 15    CND-00123218
# 16    CND-00273111
# 17    CND-00179142
# 18    CND-00236474
# 19     CND-0051931
# 20     CND-0023507
# 21     CND-0024910
# 22     CND-0025233
# 23     CND-0033896
# 24     CND-0066108
# 25    CND-00146833
# 26     CND-0082577
# 27     CND-0047606
# Name: Candidate Code, dtype: object

# %% [markdown]
# ### sorting index column wise by setting axis = 1

# %%
ch.sort_index(axis = 1)
# Out:
#    Candidate Code    Cell No.           Father Name  \
# 0     CND-0020014  3350247249      Sheikh Aslam Ali
# 1    CND-00289826  3033366843    Nasir Ali Khan Zai
# 2     CND-0054628  3342978992               Shahzad
# 3      CND-007700  3162065994           M. Alamghir
# 4    CND-00109133  3432480490          Abdul Raheem
# 5    CND-00277299  3230203128                Farooq
# 6     CND-0079382  3073223239        Khair Muhammad
# 7     CND-0080171  3045836887        Khadim Hussain
# 8     CND-0084996  3168941551              M. Umer
# 9    CND-00132394  3412680140         Nadeem Suhail
# 10    CND-0029076  3463233127       Syed Farman Ali
# 11    CND-0079781  3333327174  Karam Hussain Mirza
# 12    CND-0020583  3420465116     Rehman ullah baig
# 13    CND-0065053  3431708310             M. Asghar
# 14   CND-00171325  3092361477      anwar ali mughal
# 15   CND-00123218  3212619343      M. Zubair Shaikh
# 16   CND-00273111  3321334840      S.M Nehal Farooq
# ...

# %%
ch.sort_index(axis = 0)
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %%
ch.head(20)
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %% [markdown]
# ### deleting a particular column

# %%
del(ch['Status'])

# %%
ch
# Out:
#     S. No. Candidate Code                        Name           Father Name  \
# 0        1    CND-0020014  Sheikh Muhammad Tabish Ali      Sheikh Aslam Ali
# 1        2   CND-00289826          Adnan Ali Khan Zai    Nasir Ali Khan Zai
# 2        3    CND-0054628                  Abdul bari               Shahzad
# 3        4     CND-007700                      M. Ali           M. Alamghir
# 4        5   CND-00109133         Faheem Abdul Raheem          Abdul Raheem
# 5        6   CND-00277299                  M. Mubeen                 Farooq
# 6        7    CND-0079382          Junaid Ahmed Dahri        Khair Muhammad
# 7        8    CND-0080171           M. Wajahat Ghauri        Khadim Hussain
# 8        9    CND-0084996              M. Ammar Umer               M. Umer
# 9       10   CND-00132394                Norbin Rohan         Nadeem Suhail
# 10      11    CND-0029076    Syeda Dania Batool Abidi       Syed Farman Ali
# ...

# %%
import pandas as pd
df = pd.read_excel('F:\AI - SAYLANI COURSE - DATASETS\Final JEST - May 18-2022 at cut off 40.xls')
df
# Out:
#                                    SIBA TESTING SERVICES Unnamed: 1  \
# 0                          MERIT-TRANSPARENCY-TECHNOLOGY        NaN
# 1      RECRUITMENT TEST RESULT FOR THE POST OF JUNIOR...        NaN
# 2                   TESTS HELD: SEPTEMBER 13 TO 19, 2021        NaN
# 3                                                    NaN        NaN
# 4                                                     S#      Seat#
# ...                                                  ...        ...
# 29627                                              29623   11740110
# 29628                                              29624   11740143
# 29629                                              29625   11740328
# 29630                                              29626   11740010
# 29631                                              29627   11740009
#
#               Unnamed: 2          Unnamed: 3       Unnamed: 4 Unnamed: 5  \
# 0                    NaN                 NaN              NaN        NaN
# ...

# %%
import pandas as pd
df = pd.read_excel(r'F:\AI - SAYLANI COURSE - DATASETS\Final JEST - May 18-2022 at cut off 40.xls', index_col=0)
df
# Out:
#                                                    Unnamed: 1  \
# SIBA TESTING SERVICES
# MERIT-TRANSPARENCY-TECHNOLOGY                             NaN
# RECRUITMENT TEST RESULT FOR THE POST OF JUNIOR ...        NaN
# TESTS HELD: SEPTEMBER 13 TO 19, 2021                      NaN
# NaN                                                       NaN
# S#                                                      Seat#
# ...                                                       ...
# 29623                                                11740110
# 29624                                                11740143
# 29625                                                11740328
# 29626                                                11740010
# 29627                                                11740009
#
#                                                            Unnamed: 2  \
# SIBA TESTING SERVICES
# MERIT-TRANSPARENCY-TECHNOLOGY                                     NaN
# ...

# %% [markdown]
# ### setting index column = 0

# %%
import pandas as pd
df = pd.read_excel(r'F:\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls', index_col=0)
df
# Out:
#           Seat# Name of Candidate          Father's Name            CNIC#  \
# S#
# 1      10740353  Khalil Ul Rehman  Muhammad Iqbal Khatri  41101-8299848-7
# 2      10741027  Rafique Abdullah        Muhammad Ramzan  41101-3898195-9
# 3      10741882       Abdul Basat           Ali Muhammad  41101-3321533-9
# 4      10741513       Abdul Basit           Abdul Rehman  41104-1684255-5
# 5      10741060      Naseer Ahmed        Muhammad Yaqoob  41101-0422758-5
# ...         ...               ...                    ...              ...
# 29623  11740110       Syed Rehman             Ali Rehman  42401-8608722-5
# 29624  11740143    Zubair Rasheed     Abdul Rasheed Late  42401-2682117-7
# 29625  11740328        Shiraz Ali          Abdul Shakoor  42401-3603843-7
# 29626  11740010     Maqbool Ahmed       Muhammad  Yousuf  42401-9903963-1
# 29627  11740009             Naila        Muhammad Sharif  42401-1390031-6
#
# ...

# %%
import pandas as pd
df = pd.read_excel(r'F:\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
df
# Out:
#           S#     Seat# Name of Candidate          Father's Name  \
# 0          1  10740353  Khalil Ul Rehman  Muhammad Iqbal Khatri
# 1          2  10741027  Rafique Abdullah        Muhammad Ramzan
# 2          3  10741882       Abdul Basat           Ali Muhammad
# 3          4  10741513       Abdul Basit           Abdul Rehman
# 4          5  10741060      Naseer Ahmed        Muhammad Yaqoob
# ...      ...       ...               ...                    ...
# 29622  29623  11740110       Syed Rehman             Ali Rehman
# 29623  29624  11740143    Zubair Rasheed     Abdul Rasheed Late
# 29624  29625  11740328        Shiraz Ali          Abdul Shakoor
# 29625  29626  11740010     Maqbool Ahmed       Muhammad  Yousuf
# 29626  29627  11740009             Naila        Muhammad Sharif
#
#                  CNIC# Religion Disability      District         Taluka  \
# 0      41101-8299848-7   Muslim         No         Badin          Badin
# ...

# %% [markdown]
# ### sorting and accessing a particular record using .iloc function

# %%
df.iloc[15000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df.iloc[15000]
#
# NameError: name 'df' is not defined

# %%
df.District
# Out:
# 0               Badin
# 1               Badin
# 2               Badin
# 3               Badin
# 4               Badin
#              ...
# 29622    West Karachi
# 29623    West Karachi
# 29624    West Karachi
# 29625    West Karachi
# 29626    West Karachi
# Name: District, Length: 29627, dtype: object

# %%
df['Seat#']
# Out:
# 0        10740353
# 1        10741027
# 2        10741882
# 3        10741513
# 4        10741060
#            ...
# 29622    11740110
# 29623    11740143
# 29624    11740328
# 29625    11740010
# 29626    11740009
# Name: Seat#, Length: 29627, dtype: int64

# %% [markdown]
# ### fetching all column names in a DataFrame

# %%
df.columns
# Out:
# Index(['S#', 'Seat#', 'Name of Candidate', 'Father's Name', 'CNIC#',
#        'Religion', 'Disability', 'District', 'Taluka', 'UC', 'PhoneNumber',
#        'PermanentAddress', 'PostalAddress', 'Total Score\n(Out of 100)'],
#       dtype='object')

# %% [markdown]
# ### index column information

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29627, step=1)

# %% [markdown]
# ### converting a particular DataFrame to NumPy Array

# %%
df.to_numpy()
# Out:
# array([[1, 10740353, 'Khalil Ul Rehman', ...,
#         'Zareen House, Ward No.4, Near Head Post Office, Badin, District Badin, Sindh.',
#         'Zareen House, Ward No.4, Near Head Post Office, Badin, District Badin, Sindh.',
#         75],
#        [2, 10741027, 'Rafique Abdullah', ...,
#         'Village Allahabad Parhiar, Taluka Badin',
#         'Al-Rehman Medical Store, Seerani Road, Badin', 75],
#        [3, 10741882, 'Abdul Basat', ...,
#         'Village Andhalo P/O Badin Taluka and District Badin',
#         'Maqbool Computer composing center opposite to Molvi Haji Ahmed Mallah mosque Gharibabad Badin',
#         70],
#        ...,
#        [29625, 11740328, 'Shiraz Ali', ...,
#         'Q1/1 pak modran colony mangopir road karachi west pakistan',
#         'R 25 sector 5D sarjani town', 40],
#        [29626, 11740010, 'Maqbool Ahmed', ...,
#         'B-400 Block 3 Metroville Site Karachi',
#         'B-400 Block 3 Metroville Site Karachi', 40],
# ...

# %% [markdown]
# ### transposition

# %%
df.T
# Out:
#                                                                        0      \
# S#                                                                         1
# Seat#                                                               10740353
# Name of Candidate                                           Khalil Ul Rehman
# Father's Name                                          Muhammad Iqbal Khatri
# CNIC#                                                        41101-8299848-7
# Religion                                                              Muslim
# Disability                                                                No
# District                                                               Badin
# Taluka                                                                 Badin
# UC                                                                  MC-Badin
# PhoneNumber                                                     0333-2548228
# ...

# %%
import pandas as pd 
ch = pd.read_excel('H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch
# Out:
#           S#     Seat# Name of Candidate          Father's Name  \
# 0          1  10740353  Khalil Ul Rehman  Muhammad Iqbal Khatri
# 1          2  10741027  Rafique Abdullah        Muhammad Ramzan
# 2          3  10741882       Abdul Basat           Ali Muhammad
# 3          4  10741513       Abdul Basit           Abdul Rehman
# 4          5  10741060      Naseer Ahmed        Muhammad Yaqoob
# ...      ...       ...               ...                    ...
# 29622  29623  11740110       Syed Rehman             Ali Rehman
# 29623  29624  11740143    Zubair Rasheed     Abdul Rasheed Late
# 29624  29625  11740328        Shiraz Ali          Abdul Shakoor
# 29625  29626  11740010     Maqbool Ahmed       Muhammad  Yousuf
# 29626  29627  11740009             Naila        Muhammad Sharif
#
#                  CNIC# Religion Disability      District         Taluka  \
# 0      41101-8299848-7   Muslim         No         Badin          Badin
# ...

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
#ch.head(20)
newcol = ch['Total Score\n(Out of 100)'] 
#newcol.head(20)
#plt.plot(kind='line', x = ['Total Score\n(Out of 100)'] , y = ['District'])
plt.plot(ch['Total Score\n(Out of 100)'])
plt.show()

# %%
ch.head(20)
plt.scatter(ch['Total Score\n(Out of 100)'], ch.District)

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
plt.scatter(ch.head(20)['Total Score\n(Out of 100)'], ch.head(20).District)

# %%
ch.head(20)
# Out:
#     S#     Seat#   Name of Candidate            Father's Name  \
# 0    1  10740353    Khalil Ul Rehman    Muhammad Iqbal Khatri
# 1    2  10741027    Rafique Abdullah          Muhammad Ramzan
# 2    3  10741882         Abdul Basat             Ali Muhammad
# 3    4  10741513         Abdul Basit             Abdul Rehman
# 4    5  10741060        Naseer Ahmed          Muhammad Yaqoob
# 5    6  10740904         Hasib Ahmes           Muhammad Ilyas
# 6    7  10741918         Moiz Hassan          Muhammad Hassan
# 7    8  10741711   Furqan Ul Rasheed            Abdul Rasheed
# 8    9  10740181       Shakeel Ahmed             Abdul Jabbar
# 9   10  10740524    Allah Bux Jamali            Muhammad Alam
# 10  11  10740831          Ubaid Khan            Hashmat Ullah
# 11  12  10740854         Abdul Salam            Rasheed Ahmed
# 12  13  10741138      Ghulam Murtaza            Muhammad Khan
# 13  14  10741018          Zohaib Ali             Abdul Rasool
# ...

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch.head(20)['Total Score\n(Out of 100)'].plot(kind = "line")
plt.xlabel("No. of Students") 
plt.ylabel("Obtained Marks")
# Out:
# Text(0, 0.5, 'Obtained Marks')

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch.head(20)['Total Score\n(Out of 100)'].plot(kind = "bar")
plt.title("SIBA Test - JEST Result 2021")
plt.xlabel("No. of Students") 
plt.ylabel("Obtained Marks")
# Out:
# Text(0, 0.5, 'Obtained Marks')

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch.head(20)['Total Score\n(Out of 100)'].plot(kind = "hist")
plt.xlabel("Obtained Marks")
plt.ylabel("No. of Students")
# Out:
# Text(0, 0.5, 'No. of Students')

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch.head(100)['Total Score\n(Out of 100)'].plot(kind = "line")
plt.title("SIBA Test - JEST Result 2021")
plt.xlabel("No. of Students") 
plt.ylabel("Obtained Marks")
# Out:
# Text(0, 0.5, 'Obtained Marks')

# %%
from matplotlib import pyplot as plt 
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch.head(20)
# Out:
#     S#     Seat#   Name of Candidate            Father's Name  \
# 0    1  10740353    Khalil Ul Rehman    Muhammad Iqbal Khatri
# 1    2  10741027    Rafique Abdullah          Muhammad Ramzan
# 2    3  10741882         Abdul Basat             Ali Muhammad
# 3    4  10741513         Abdul Basit             Abdul Rehman
# 4    5  10741060        Naseer Ahmed          Muhammad Yaqoob
# 5    6  10740904         Hasib Ahmes           Muhammad Ilyas
# 6    7  10741918         Moiz Hassan          Muhammad Hassan
# 7    8  10741711   Furqan Ul Rasheed            Abdul Rasheed
# 8    9  10740181       Shakeel Ahmed             Abdul Jabbar
# 9   10  10740524    Allah Bux Jamali            Muhammad Alam
# 10  11  10740831          Ubaid Khan            Hashmat Ullah
# 11  12  10740854         Abdul Salam            Rasheed Ahmed
# 12  13  10741138      Ghulam Murtaza            Muhammad Khan
# 13  14  10741018          Zohaib Ali             Abdul Rasool
# ...

# %%
ch['Name of Candidate']
# Out:
# 0        Khalil Ul Rehman
# 1        Rafique Abdullah
# 2             Abdul Basat
# 3             Abdul Basit
# 4            Naseer Ahmed
#                ...
# 29622         Syed Rehman
# 29623      Zubair Rasheed
# 29624          Shiraz Ali
# 29625       Maqbool Ahmed
# 29626               Naila
# Name: Name of Candidate, Length: 29627, dtype: object

# %%
type(ch['Name of Candidate'])
# Out:
# pandas.core.series.Series

# %%
ch.head(20)[['Name of Candidate']]
# Out:
#      Name of Candidate
# 0     Khalil Ul Rehman
# 1     Rafique Abdullah
# 2          Abdul Basat
# 3          Abdul Basit
# 4         Naseer Ahmed
# 5          Hasib Ahmes
# 6          Moiz Hassan
# 7    Furqan Ul Rasheed
# 8        Shakeel Ahmed
# 9     Allah Bux Jamali
# 10          Ubaid Khan
# 11         Abdul Salam
# 12      Ghulam Murtaza
# 13          Zohaib Ali
# 14      Ashfaque Ahmed
# 15         Hafeezullah
# 16    Muhammad Hussain
# 17          Hassan Ali
# 18               Kabir
# 19  Aftab Ahmed Samoon

# %%
ch.head(20)[['Name of Candidate', 'PhoneNumber']]
# Out:
#      Name of Candidate   PhoneNumber
# 0     Khalil Ul Rehman  0333-2548228
# 1     Rafique Abdullah  0304-9303069
# 2          Abdul Basat  0301-3144849
# 3          Abdul Basit  0333-2531085
# 4         Naseer Ahmed  0336-1359004
# 5          Hasib Ahmes  0332-2951392
# 6          Moiz Hassan  0333-2524237
# 7    Furqan Ul Rasheed  0333-7437649
# 8        Shakeel Ahmed  0316-3996373
# 9     Allah Bux Jamali  0333-2505055
# 10          Ubaid Khan  0314-6652880
# 11         Abdul Salam  0311-3694640
# 12      Ghulam Murtaza  0332-2647870
# 13          Zohaib Ali  0345-3317714
# 14      Ashfaque Ahmed  0332-3518559
# 15         Hafeezullah  0332-2951260
# 16    Muhammad Hussain  0340-0089174
# 17          Hassan Ali  0333-2528887
# 18               Kabir  0332-3023392
# 19  Aftab Ahmed Samoon  0309-6108988

# %%
type(ch.head(20)[['Name of Candidate', 'PhoneNumber']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(ch.head(20)[['Name of Candidate']])
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd 
ch = pd.read_excel(r'H:\SAYLANI DSC COURSE\AI - SAYLANI COURSE - DATASETS\DATASET - Final JEST - May 18-2022 at cut off 40.xls')
ch.head(15)[['S#', 'Seat#', 'Name of Candidate', 'Father\'s Name', 'CNIC#', 'PhoneNumber', 'Total Score\n(Out of 100)']]
# Out:
#     S#     Seat#  Name of Candidate          Father's Name            CNIC#  \
# 0    1  10740353   Khalil Ul Rehman  Muhammad Iqbal Khatri  41101-8299848-7
# 1    2  10741027   Rafique Abdullah        Muhammad Ramzan  41101-3898195-9
# 2    3  10741882        Abdul Basat           Ali Muhammad  41101-3321533-9
# 3    4  10741513        Abdul Basit           Abdul Rehman  41104-1684255-5
# 4    5  10741060       Naseer Ahmed        Muhammad Yaqoob  41101-0422758-5
# 5    6  10740904        Hasib Ahmes         Muhammad Ilyas  41101-2524716-1
# 6    7  10741918        Moiz Hassan        Muhammad Hassan  41101-9372102-1
# 7    8  10741711  Furqan Ul Rasheed          Abdul Rasheed  41101-9215800-1
# 8    9  10740181      Shakeel Ahmed           Abdul Jabbar  41303-5405070-3
# 9   10  10740524   Allah Bux Jamali          Muhammad Alam  41101-6552645-3
# 10  11  10740831         Ubaid Khan          Hashmat Ullah  41101-1852031-1
# ...
